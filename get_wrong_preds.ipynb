# %%
import pandas as pd

df = pd.read_csv('./far_bias/preds_far_bias.csv')
df = df[df['preds_raw_1']>.2]

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   isv_dst  effect_dst  isv_bin  effect_bin  \
# 1               1         645 -0.997365   -1.155688        3           5
# 31             31          11 -1.371503    0.575626        2           7
# 34             34          79 -1.484115    2.523529        2           8
# 63             63          61 -1.224618   -0.339207        2           6
# 66             66         756 -1.487414   -0.767004        2           5
# 104           104         265 -1.424246    1.511109        2           6
# 109           109         705 -1.314271    0.491778        2           4
# 147           147         572 -0.977588   -1.174041        3           5
# 165           165          41 -1.177156   -0.149033        2           6
# 173           173         121 -1.604704    0.408972        2           4
# 177           177         544 -1.825356    0.626396        1           4
# 195           195         614 -1.692532    1.756800        1           6
# ...

# %%
df2 = df[df['preds_raw_1']>.5]
df2
# Out:
#      Unnamed: 0.1  Unnamed: 0   isv_dst  effect_dst  isv_bin  effect_bin  \
# 31             31          11 -1.371503    0.575626        2           7
# 63             63          61 -1.224618   -0.339207        2           6
# 165           165          41 -1.177156   -0.149033        2           6
# 173           173         121 -1.604704    0.408972        2           4
# 177           177         544 -1.825356    0.626396        1           4
# 198           198         746 -1.618508    2.321818        2           7
# 216           216          43 -2.019981    1.076140        1           5
# 230           230         483 -2.480453    1.049686        0           5
# 246           246         102  0.563755    0.076722        5           7
#
#     both_bins  bias_label  ground_truth strat_col  \
# 31        2_7           1             0   0_1_7_2
# 63        2_6           1             0   0_1_6_2
# 165       2_6           1             0   0_1_6_2
# ...

# %%
lst = [x for x in df2['Unnamed: 0.1']]

# %%
lst
# Out:
# [31, 63, 165, 173, 177, 198, 216, 230, 246]

# %%
1-16/248
# Out:
# 0.935483870967742
